# %%
sevenWordGrammar = """   
      S:{<NP><VP>} 
      NP:{<ADJ>*<N>*<P>?<ADJ>*<N>+|<PN><ADJ>?<N>*<ADJ>?<N><P>?|<N><CJ><N>|<N>?<DET>?<ADJ>?<N>+<ADJ>?<N>?|<N><ADJ><N>}
      PP:{<P><N>?|<P><PP>}
      ADP:{<P>?<ADV><DET>|<P>?<ADV><ADJ>|<PP>?<ADV>+<NP>?<ADJ>?<DET>?}
      AJP:{<DET>?<ADJ>|<ADJ>}
      VP:{<PP>?<V>|<ADP>?<V>|<ADV>?<V>|<AJP><V>}                     
    """
sixWordGrammar = """   
      S:{<NP><VP>} 
      NP:{<N>*<CJ>?<N><ADJ>*<N>*|<ADJ>*<N>*<ADJ>?<N>|<N>?<DET>?<ADJ>*<N>+<ADJ>?|<N><ADJ><N>|<P><ADJ><N>}
      PP: {<P><N>|<P><PP>}
      ADP:{<ADV><DET>|<ADV><AD>|<PP>?<ADV>+<NP>?<ADJ>?}
      AJP:{<DET>?<ADJ>|<ADJ>}
      VP:{<N>?<V>|<ADP>?<V>|<ADV>?<V>|<AJP><V>}                     
    """
twoWordGrammar = """   
      S:{<NP><VP>}  
      NP:{<N>}
      VP:{<V>}                      
    """
threeWordGrammar = """   
      S:{<NP><VP>}  
      NP:{<PN>|<N><N>|<ADJ>?<NUM>?<N>}
      VP:{<ADJ>?<V>|<ADV>?<V>}                      
    """
fourWordGrammar = """   
      S:{<NP><VP>} 
      NP:{<NUM>?<N>?<DET>?<ADJ>*<N>+<P>?|<N><ADJ>*<N>|<P><ADJ>*<N>|<N><CJ><N>|<ADV><P><N>}
      PP: {<P><N>?|<N><P>|<P>+}
      ADP:{<ADV><DET>?|<PP>?<ADV>|<AJP>|<ADJ><N>|<ADP>}    
      AJP:{<DET><ADJ>}
      VP:{<ADP><V>|<ADV><V>|<P><V>|<V>}                      
    """
fiveWordGrammar = """   
      S:{<NP><VP>} 
      NP:{<ADJ>?<PN>?<N>*<ADJ>*<N><PN>?<N>?|<N><PN>?<CJ><PN>?<N>|<PN>?<N>?<DET>?<ADJ>*<N>+<ADJ>?|<N><PN>?<ADJ>*<N><PN>?|<P><ADJ><PN>?<N>}
      PP: {<P><N>|<P><PP>}
      ADP:{<ADV><AD>|<PP>?<DET>?<ADV>+<NP>?<ADJ>?}
      AJP:{<DET>?<ADJ>|<ADJ>}
      VP:{<N>?<V>|<ADP>?<V>|<ADV>?<V>|<AJP><V>}                      
    """
bookGrammar = """   
     S:{<NP><VP>|<N><VP>}  
     PP:{<P><N>|<N><P>|<P><PP>}
     AJP:{<DET>*<PP>*<ADJ>}
     NP:{<DET><N>+|<ADP>*<N>+|<N>}
     NP:{<NP><PP><NP>|<NP><AJP><NP>|<DET>*<AJP><NP>} 
     ADP:{<DET>?<PP>?<ADV>}
     VP:{<PP><V>|<PP><NP><V>|<ADP>*<V>|<AJP><V>|<N><V>}
     VP:{<PP><VP>|<V>+}
"""
GeneralGrammar1 = """   
     S:{<NP><VP>}    
    NP:{<N>?|<s><V>} 
    s:{<PP><N>}
    NP:{<ADJ><N>|<N><N><P>|<ADV><N>|<N><V><N>|<N><C><C>|<N><N><V><P>|<NUM><P><ADJ><N>}
    VP:{<s><V>}
    s:{<NP><PP>|<NP><PP><V>}
    VP:{<ADV><ADJ><V>|<P><V>}
    NP:{<N><V><N>|<N><NP>|<NP><N>}
    VP:{<ADV><V>|<N><PP>|<s><NP><V>}
    s:{<P><V>}
    NP:{<NUM><N>}
    VP:{<ADV><VP>}
    PP:{<N><P>|<P><N><P>}
    ADJP:{<ADV><ADJ>|<ADJ>}
    ADVP:{<ADV>}
    VP:{<PP><V>|<N><VP>|<N><V>|<NP><V>|<ADV><V>|<ADJP><V>|<ADV><VP>|<V><V>}
    NP:{<N><N>|<N><NP>|<NP><N>|<ADJ><NP>|<N><C><N>|<N><P>}
    PP:{<P><N>}
    VP:{<ADJ><V>|<ADV><N><V>|<PP><N><V>|<NP><PP><ADV><V>}
"""


GeneralGrammar = """   
      S:{<NP><VP>} 
      NP:{<PN><ADJ>?<N>*<ADJ>?<N>*<CJ>?<ADJ>*<N>|<N><CJ><N>|<N>*<DET>?<ADJ>?<N>+<CJ>?<ADJ>?<N>*<CJ>?<ADJ>*<N>*|<N><ADJ><N>|<P><ADJ><N>}
      PP:{<P><N>?|<P><PP>}
      ADP:{<P>?<ADV><DET>|<P>?<ADV><ADJ>|<PP>?<ADV>+<NP>?<ADJ>?<ADJ>?<DET>?}
      AJP:{<DET>?<ADJ>|<ADJ>}
      VP:{<PP>?<V>|<ADP>?<V>|<ADV>?<V>|<AJP><V>}                     
    """
