# %%
# %run ./Corpus_Reader.ipynb
import nltk
from nltk.corpus.reader import TaggedCorpusReader
from nltk import word_tokenize
import re

POS_Tagger=[]    
verbs=[]
nouns=[]  
adjectives=[]   
prepositions=[] 
pronouns=[] 
adverbs=[]
numbers=[]
conjunctions=[]

for i in range(0,len(wordscorpus)-1,1):

    if(wordscorpus[i]=='v' or wordscorpus[i]=='V'):

        verbs.append((wordscorpus[i+1]))

    if(wordscorpus[i]=='n' or wordscorpus[i]=='N'):

        nouns.append((wordscorpus[i+1]))

    if(wordscorpus[i]=='adj' or wordscorpus[i]=='Adj' or wordscorpus[i]=='ADJ'):

        adjectives.append((wordscorpus[i+1]))          

    if(wordscorpus[i]=='PREP' or wordscorpus[i]=='prep' or wordscorpus[i]=='Prep'):

        prepositions.append((wordscorpus[i+1]))

    if(wordscorpus[i]=='pron' or wordscorpus[i]=='PRON' or wordscorpus[i]=='Pron' ):

        pronouns.append((wordscorpus[i+1]))

    if(wordscorpus[i]=='adv' or wordscorpus[i]=='ADV' or wordscorpus[i]=='Adv'):

        adverbs.append((wordscorpus[i+1])) 

#for pronun in pronunsCorpus:

#   pronouns.append((pronun))

#for preposition in PrepositionCorpus:

#    prepositions.append((preposition))

#for number in NumberCorpus:

#    numbers.append((number))

#for conjunction in conjunctionsCorpus:

#    conjunctions.append((conjunction))


uniqueVerbs = set(verbs)
uniqueNouns = set(nouns)
uniqueAdjectives = set(adjectives)
uniquePrepositions = set(prepositions)
uniquePronouns = set(pronouns)
uniqueAdverbs = set(adverbs)
uniqueNumbers = set(numbers)
uniqueConjunctions = set(conjunctions)


#POS_Tagger.extend( (('ካሳ','N'),('እደሰራች','V'),('በላ','V'),('ሰምቷል','V'),('ይሰራል','V'),('በጣም','DET'),('ክፉኛ','ADV'),('ለ','P'),('በ','P'),('ተሸጠ','V'),('ያ','DET'),('ሁለት','DET'),('ንጹህ','ADJ'),('በጣም','DET'),('እንደ','P'),('ወንድሙ','N'),('ሰው','N')))


#POS_Tagger.extend( (('እንደበላ','ADV'),('በልቶ','ADV'),('ነው','V'),('ሄደ','V'),('በንጋት','ADJ'),('የሸጠለትን','ADJ'),('ከተማ','N'),('ያበራሉ','V'),('በጣም','ADJ'),('አመሰገኑ','V'),('በውስጡ','PR'),('ስለያዘ','ADV'),('ከበደኝ','V')))

for Pronoun in uniquePronouns:

    POS_Tagger.append((Pronoun,'PN'))
    print(POS_Tagger)

for adjective in Adjectiveswordscorpus:

    POS_Tagger.append((adjective,'ADJ'))
    print(POS_Tagger)

for noun in Nounswordscorpus:

    POS_Tagger.append((noun,'N'))
    

for verb in Verbswordscorpus:

    POS_Tagger.append((verb,'V'))


for preposition in uniquePrepositions:

    POS_Tagger.append((preposition,'P'))

for adverb in uniqueAdverbs:

    POS_Tagger.append((adverb,'ADV'))

for number in uniqueNumbers:

    POS_Tagger.append((number,'NUM'))  

POS_Tagger.append((r'[0-9]','NUM'))

for conjunction in uniqueConjunctions:

    POS_Tagger.append((conjunction,'CJ'))

POS_Tagger.append((r'.*','N'))
# Out:
# ('እንሞካከርለሞመከር', 'V')
# ('ቀጠሮ', 'V')
# ('በላ', 'V')
# ('ነው', 'V')
# ('ወርደው', 'V')
# ('አሰልጥነው', 'V')
# ('ስለመወገዳቸው', 'V')
# ('አሰማርቶ', 'V')
# ('ሰጤ', 'V')
# ('በመሙላታቸው', 'V')
# ('እየጣሰች', 'V')
# ('ካለፈው', 'V')
# ('አከሰሰረ', 'V')
# ('አስተዋወቁ', 'V')
# ('አጨሰ', 'V')
# ('ተበሳጨ', 'V')
# ('አደገ', 'V')
# ('አወለቀ', 'V')
# ('ተመለከከተ', 'V')
# ('ማግኘት', 'V')
# ('ተደንግጓል', 'V')
# ('አላማዎች', 'V')
# ('ቀላ', 'V')
# ('ተረጋገጦ', 'V')
# ('አንከባለለ', 'V')
# ('አልሆኑም', 'V')
# ('ይፈጥራል', 'V')
# ('ፈነዳ', 'V')
# ('ማቃጠር', 'V')
# ('እየተዳከመ', 'V')
# ('አለመኖሩ', 'V')
# ('ይደረግላቸዋል', 'V')
# ('ትልምአበጀ', 'V')
# ('ወስኗል', 'V')
# ('ተገምቶ', 'V')
# ('ተጨማደደ', 'V')
# ('አፈጠነ', 'V')
# ('ወጠረ', 'V')
# ('ተሰራጨ', 'V')
# ('አይኖረውም', 'V')
# ('ይጀምራል', 'V')
# ('ጠፋ', 'V')
# ('አይጠቀስ', 'V')
# ('ደጋግሞአጠና', 'V')
# ('አዘዘ', 'V')
# ('ያቀርባቸዋል', 'V')
# ('ጫረ', 'V')
# ('አግኝተው', 'V')
# ('የተረከበው', 'V')
# ('ሲሉ', 'V')
# ('እየተመቻቸ', 'V')
# ('አድንቀዋል', 'V')
# ('አውስተዋል', 'V')
# ('ቀዳሚነትያዘ', 'V')
# ('አሶሺየትድ', 'V')
# ('ተንቀሳቅው', 'V')
# ('ጠመዝማዛ', 'V')
# ('አደራጅቶ', 'V')
# ('አንገላታ', 'V')
# ...
